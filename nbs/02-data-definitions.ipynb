# %% [markdown]
# # Defining Outputs & Inputs
#
# <br>
#
# ### Imports

# %%
import json
import pandas as pd

import os
from typing import Any

# %%
from IPython.display import JSON

# %% [markdown]
# <br>
#
# ### User Inputs

# %%
raw_data_dir = '../data/raw'
definitions_dir = '../data/definitions'

# %% [markdown]
# <br>
#
# ### Output Definitions
#
# Before we collate the data sources into a single dataset we want to first define the attribute sets we want to have in our outputs.

# %%
outputs = {
    'name': 'str',
    'sett_bmu_id': 'str',
    'longitude': 'float',
    'latitude': 'float',
    'capacity_mw': 'float',
    'fuel_type': [
        'gas',
        'coal',
        'wind',
        'solar',
        'oil',
        'hydro',
        'nuclear',
        'biomass',
        'other' # e.g. for batteries or aggregators
    ],
    'plant_type': [
        'ccgt',
        'ocgt',
        'coal',
        'onshore_wind',
        'offshore_wind',
        'floating_wind',
        'conc_solar',
        'pv_solar',
        'oil',
        'run_of_river',
        'pumped_storage',
        'nuclear',
        'aggregator',
        'battery',
        'biomass',
        'other' # ideally no plants should come under this, the preference is to create a new category
    ]
}

JSON(outputs)

# %% [markdown]
# <br>
#
# We'll save this to the definitions directory

# %%
with open(f'{definitions_dir}/outputs.json', 'w') as f:
    json.dump(outputs, f)

# %% [markdown]
# <br>
#
# ### Source Definitions
#
# #### ESAIL
#
# We'll start by loading the ESAIL dataset in

# %%
filename = 'ESAIL.csv'

df_ESAIL = pd.read_csv(f'{raw_data_dir}/{filename}')

df_ESAIL.head()
# Out:
#   sett_bmu_id ngc_bmu_id bmu_root                    name primary_fuel_type  \
# 0    E_MARK-1     MARK-1     MARK  Rothes Bio-Plant CHP 1           biomass
# 1    E_MARK-2     MARK-2     MARK  Rothes Bio-Plant CHP 2           biomass
# 2     T_DIDC1      DIDC1     DIDC          Didcot A (G) 1              coal
# 3     T_DIDC2      DIDC2     DIDC          Didcot A (G) 2              coal
# 4     T_DIDC4      DIDC4     DIDC          Didcot A (G) 4              coal
#
#   detailed_fuel_type  longitude   latitude           common_name
# 0               bone  -3.603516  57.480403  Rothes Bio-Plant CHP
# 1               bone  -3.603516  57.480403  Rothes Bio-Plant CHP
# 2    coalgas_opt_out  -1.267570  51.623630          Didcot A (G)
# 3    coalgas_opt_out  -1.267570  51.623630          Didcot A (G)
# 4    coalgas_opt_out  -1.267570  51.623630          Didcot A (G)

# %% [markdown]
# <br>
#
# We'll then define the key column, as well as the mapping from the OSUKED key to the ESAIL key

# %%
def check_key_input_col(df, key_input_col):
    df[key_input_col].isnull().sum() == 0, f'{key_input_col} can not contain missing values'
    return df

key_input_col = 'bmu_root'
key_output_col = 'esail_id'

key_map = (df_ESAIL
           .pipe(check_key_input_col, key_input_col)
           [[key_input_col]]
           .drop_duplicates()
           .reset_index()
           .pipe(lambda df: df.assign(index=df.index+10000))
           .set_index('index')
           [key_input_col]
           .to_dict()
          )

JSON([key_map])

# %% [markdown]
# <br>
#
# We'll also define how we want to extract data from the attribute columns, specifically we provide the name of the new output column, the rank of the source in regards to this column, and the value mapping necessary for that columns content to match the desired output.

# %%
attr_cols = {
    'common_name': {
        'output_col': 'name',
        'output_rank': 0, 
        'value_map': None
    },
    'sett_bmu_id': {
        'output_col': 'sett_bmu_id',
        'output_rank': 0, 
        'value_map': None
    },
    'longitude': {
        'output_col': 'longitude',
        'output_rank': 0, 
        'value_map': None
    },
    'latitude': {
        'output_col': 'latitude',
        'output_rank': 0, 
        'value_map': None
    },
    'primary_fuel_type': {
        'output_col': 'fuel_type',
        'output_rank': 0, # rank to determine which input to use when multiple are provided, 0 is highest
        'value_map': {
            'wind': 'wind', 
            'gas': 'gas', 
            'coal': 'coal', 
            'fuel_oil': 'oil', 
            'nuclear': 'nuclear', 
            'run_of_river': 'hydro',
            'pumped_storage': 'hydro', 
            'aggregator': 'other', 
            'other': 'other', 
            'rgt': 'gas', 
            'biomass': 'biomass', 
            'battery': 'other'
        }
    }
}

# %% [markdown]
# <br>
#
# We can now combine this into a single metadata object for the source

# %%
ESAIL_def = {
    'filename': filename,
    'key_input_col': key_input_col,
    'key_output_col': key_output_col,
    'key_map': key_map,
    'attr_cols': attr_cols
}

JSON(ESAIL_def)

# %% [markdown]
# <br>
#
# We'll save this source definition before moving on

# %%
with open(f'{definitions_dir}/ESAIL.json', 'w') as f:
    json.dump(ESAIL_def, f)

# %% [markdown]
# <br>
#
# #### OPSD

# %%
filename = 'OPSD.csv'

df_OPSD = pd.read_csv(f'{raw_data_dir}/{filename}')

df_OPSD.head()
# Out:
#                           name         company street postcode city country  \
# 0  Marcinelle Energie (Carsid)  DIRECT ENERGIE    NaN      NaN  NaN      BE
# 1               Aalst Syral GT      Electrabel    NaN      NaN  NaN      BE
# 2               Aalst Syral ST      Electrabel    NaN      NaN  NaN      BE
# 3                    AALTER TJ      Electrabel    NaN      NaN  NaN      BE
# 4            Amercoeur 1 R TGV      Electrabel    NaN      NaN  NaN      BE
#
#    capacity energy_source      technology  chp  ...     type       lat  \
# 0     413.0   Natural gas  Combined cycle  NaN  ...      NaN  50.41396
# 1      43.0   Natural gas     Gas turbine  Yes  ...  CHP/IPP       NaN
# 2       5.0   Natural gas   Steam turbine  Yes  ...  CHP/IPP       NaN
# 3      18.0           Oil     Gas turbine  NaN  ...      NaN       NaN
# 4     451.0   Natural gas  Combined cycle  NaN  ...      NaN  50.43004
#
#        lon          eic_code energy_source_level_1 energy_source_level_2  \
# 0  4.40645  22WMARCIN000179H          Fossil fuels           Natural gas
# 1      NaN               NaN          Fossil fuels           Natural gas
# 2      NaN               NaN          Fossil fuels           Natural gas
# 3      NaN               NaN          Fossil fuels                   Oil
# 4  4.39518  22WAMERCO000010Y          Fossil fuels           Natural gas
#
#   energy_source_level_3 additional_info comment  \
# 0                   NaN             NaN     NaN
# 1                   NaN             NaN     NaN
# 2                   NaN             NaN     NaN
# 3                   NaN             NaN     NaN
# 4                   NaN             NaN     NaN
#
#                                               source
# 0  https://www.elia.be/en/grid-data/power-generat...
# 1  https://www.elia.be/en/grid-data/power-generat...
# 2  https://www.elia.be/en/grid-data/power-generat...
# 3  https://www.elia.be/en/grid-data/power-generat...
# 4  https://www.elia.be/en/grid-data/power-generat...
#
# [5 rows x 21 columns]

# %%
df_OPSD_UK.iloc[0]
# Out:
# name                                                  Drax - biomass units
# company                                                         Drax Power
# street                                                                 NaN
# postcode                                                               NaN
# city                                                                   NaN
# country                                                                 UK
# capacity                                                              2640
# energy_source                                           Biomass and biogas
# technology                                                             NaN
# chp                                                                    NaN
# commissioned                                                          2013
# type                                                                   NaN
# lat                                                                53.7365
# lon                                                              -0.996463
# eic_code                                                  48WSTN0000DRAXXK
# energy_source_level_1                                     Renewable energy
# energy_source_level_2                                            Bioenergy
# energy_source_level_3                                   Biomass and biogas
# additional_info                                                        NaN
# comment                                                                NaN
# source                   https://www.gov.uk/government/statistics/elect...
# Name: 2867, dtype: object

# %%
core_cols = ['name', 'capacity', 'energy_source', 'capacity', 'eic_code', 'lat', 'lon']
df_OPSD_UK = df_OPSD.query('country=="UK"').sort_values('capacity', ascending=False)[core_cols]

print(f'There are {df_OPSD_UK.shape[0]} power plant entries for the UK')

df_OPSD_UK.head(20)
# Out:
# There are 244 power plant entries for the UK
#                       name  capacity       energy_source  capacity  \
# 2867  Drax - biomass units    2640.0  Biomass and biogas    2640.0
# 2960              Pembroke    2199.0         Natural gas    2199.0
# 3083             Ratcliffe    2021.0           Hard coal    2021.0
# 2888                Cottam    2000.0           Hard coal    2000.0
# 2889           West Burton    2000.0           Hard coal    2000.0
# 2967       Fiddler’s Ferry    1961.0           Hard coal    1961.0
# 2904              Dinorwig    1800.0               Hydro    1800.0
# 2961          Staythorpe C    1772.0         Natural gas    1772.0
# 2928            Aberthaw B    1559.0           Hard coal    1559.0
# 3089           Grain CHP *    1517.0         Natural gas    1517.0
# 2957              Didcot B    1450.0         Natural gas    1450.0
# 3091          Connahs Quay    1380.0         Natural gas    1380.0
# 2913     South Humber Bank    1365.0         Natural gas    1365.0
# 2893      West Burton CCGT    1332.0         Natural gas    1332.0
# 2868     Drax - coal units    1320.0           Hard coal    1320.0
# 2897             Heysham 2    1254.0             Nuclear    1254.0
# 3100       VPI Immingham *    1252.0         Natural gas    1252.0
# 2901               Torness    1250.0             Nuclear    1250.0
# 2962               Seabank    1234.0         Natural gas    1234.0
# 2900            Sizewell B    1223.0             Nuclear    1223.0
#
#               eic_code        lat       lon
# 2867  48WSTN0000DRAXXK  53.736480 -0.996463
# 2960  48WSTN00000PEMBL  51.684356 -4.996698
# 3083  48WSTN00000RATS9  52.865241 -1.254127
# 2888  48WSTN1000COTPSQ  53.303711 -0.778882
# 2889  48WSTN0000WBUPSE  53.361541 -0.810597
# 2967  48WSTN00000FIDLP  53.372319 -2.686950
# 2904  48WSTN10000DINOQ  53.118744 -4.113624
# 2961  48WSTN00000STAYA  53.073732 -0.858784
# 2928  48WSTN0000ABTHBN  51.387471 -3.406652
# 3089  48WSTN0000GRAINU  51.445227  0.715005
# 2957  48WSTN0000DIDCBC  51.624573 -1.266460
# 3091  48WSTN0000CNQPSG  53.231501 -3.081939
# 2913  48WSTN00000SHBAT  53.602042 -0.144875
# 2893  48WSTN0000WBURB5  53.361541 -0.810597
# 2868  48WSTN0000DRAXXK  53.736480 -0.996463
# 2897  48WSTN0000HEYM2N  54.029263 -2.915381
# 3100  48WSTN00000HUMR2  53.638708 -0.234093
# 2901  48WSTN00000TORNX  55.967523 -2.407059
# 2962               NaN        NaN       NaN
# 2900  48WSTN00000SIZBP  52.215110  1.620130

# %%
df_ESAIL[df_ESAIL['name'].str.lower().str.contains('drax').fillna(False)]
# Out:
#      sett_bmu_id ngc_bmu_id bmu_root      name primary_fuel_type  \
# 12     T_DRAXX-1    DRAXX-1    DRAXX      Drax              coal
# 13     T_DRAXX-2    DRAXX-2    DRAXX      Drax              coal
# 14     T_DRAXX-3    DRAXX-3    DRAXX      Drax              coal
# 15     T_DRAXX-4    DRAXX-4    DRAXX      Drax              coal
# 16     T_DRAXX-5    DRAXX-5    DRAXX      Drax              coal
# 17     T_DRAXX-6    DRAXX-6    DRAXX      Drax              coal
# 183  T_DRAXX-10G  DRAXX-10G   DRAXXG  Drax AGT          fuel_oil
# 184  T_DRAXX-12G  DRAXX-12G   DRAXXG  Drax AGT          fuel_oil
# 185   T_DRAXX-9G   DRAXX-9G   DRAXXG  Drax AGT          fuel_oil
#
#     detailed_fuel_type  longitude   latitude common_name
# 12         coal_opt_in  -0.626221  53.748711        Drax
# 13         coal_opt_in  -0.626221  53.748711        Drax
# 14         coal_opt_in  -0.626221  53.748711        Drax
# 15         coal_opt_in  -0.626221  53.748711        Drax
# 16         coal_opt_in  -0.626221  53.748711        Drax
# 17         coal_opt_in  -0.626221  53.748711        Drax
# 183             gasoil  -0.999021  53.737546    Drax AGT
# 184             gasoil  -0.999021  53.737546    Drax AGT
# 185             gasoil  -0.999021  53.737546    Drax AGT

# %% [markdown]
# <br>
#
# #### GPPDB

# %%
filename = 'GPPDB.csv'

df_GPPDB = pd.read_csv(f'{raw_data_dir}/{filename}')

df_GPPDB.head()
# Out:
#   country country_long                                              name  \
# 0     AFG  Afghanistan      Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan                                      Kandahar DOG
# 2     AFG  Afghanistan                                      Kandahar JOL
# 3     AFG  Afghanistan     Mahipar Hydroelectric Power Plant Afghanistan
# 4     AFG  Afghanistan  Naghlu Dam Hydroelectric Power Plant Afghanistan
#
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0  GEODB0040538         33.0    32.322    65.1190        Hydro         NaN
# 1    WKS0070144         10.0    31.670    65.7950        Solar         NaN
# 2    WKS0071196         10.0    31.623    65.7920        Solar         NaN
# 3  GEODB0040541         66.0    34.556    69.4787        Hydro         NaN
# 4  GEODB0040534        100.0    34.641    69.7170        Hydro         NaN
#
#   other_fuel2  ... geolocation_source  wepp_id year_of_capacity_data  \
# 0         NaN  ...              GEODB  1009793                2017.0
# 1         NaN  ...         Wiki-Solar      NaN                   NaN
# 2         NaN  ...         Wiki-Solar      NaN                   NaN
# 3         NaN  ...              GEODB  1009795                2017.0
# 4         NaN  ...              GEODB  1009797                2017.0
#
#   generation_gwh_2013 generation_gwh_2014 generation_gwh_2015  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#   generation_gwh_2016  generation_gwh_2017  generation_data_source  \
# 0                 NaN                  NaN                     NaN
# 1                 NaN                  NaN                     NaN
# 2                 NaN                  NaN                     NaN
# 3                 NaN                  NaN                     NaN
# 4                 NaN                  NaN                     NaN
#
#    estimated_generation_gwh
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# <br>
#
# First we need to filter this down to plants in the UK.
#
# N.b. the GPPDB uses United Kingdom and GBR interchangeably which is particularly confusing when they're using separate networks - in this work we are currently focusing on GBR only.

# %%
df_GPPDB_UK = df_GPPDB.query('country=="GBR"')

print(f'There are {df_GPPDB_UK.shape[0]} power plant entries for the UK')
# Out:
# There are 2603 power plant entries for the UK

# %% [markdown]
# <br>
#
# Looking at the sources we can see that most of these come from the renewable energy planning database which includes a large number of relatively small plants

# %%
df_GPPDB_UK['geolocation_source'].value_counts()
# Out:
# UK Renewable Energy Planning Database    2413
# Wiki-Solar                                 67
# GEODB                                      57
# CARMA                                      50
# GEO                                         9
# WRI                                         7
# Name: geolocation_source, dtype: int64

# %% [markdown]
# <br>
#
# Looking at the average capacity of each source makes this clearer

# %%
df_GPPDB_UK.groupby(df_GPPDB_UK['geolocation_source'])['capacity_mw'].mean().sort_values(ascending=False)
# Out:
# geolocation_source
# GEODB                                    800.640351
# WRI                                      475.957143
# GEO                                      413.444444
# CARMA                                     50.699000
# UK Renewable Energy Planning Database     13.341912
# Wiki-Solar                                 7.889552
# Name: capacity_mw, dtype: float64

# %% [markdown]
# <br>
#
# Sorting by capacity gives us a good basis for selecting which plants to start manually matching ids with

# %%
df_GPPDB_UK_focused_sorted = df_GPPDB_UK.sort_values('capacity_mw', ascending=False)[['gppd_idnr', 'name', 'capacity_mw', 'latitude', 'longitude', 'primary_fuel', 'other_fuel1']]

df_GPPDB_UK_focused_sorted.head()
# Out:
#         gppd_idnr         name  capacity_mw  latitude  longitude primary_fuel  \
# 23794  GBR1000372     Pembroke       2180.0   51.6850    -4.9900          Gas
# 24421  GBR1000143  West Burton       2012.0   53.3604    -0.8102         Coal
# 22534  GBR1000142       Cottam       2008.0   53.3040    -0.7815         Coal
# 23888  GBR1000496    Ratcliffe       2000.0   52.8653    -1.2550         Coal
# 22663  GBR0000174         Drax       1980.0   53.7356    -0.9911         Coal
#
#       other_fuel1
# 23794         NaN
# 24421         NaN
# 22534         NaN
# 23888         NaN
# 22663     Biomass

# %% [markdown]
# <br>
#
# These were then manually matched to the BMU ids in the ESAIL dataset, confirming matches based on fuel, location and capacity (checked on NETA-Reports)

# %%
BMU_root_to_gppd_idnr = {
    'HEYM2': 'GBR1000055', # Heysham 2 - complicated one, need to have HEYM1 and HEYM2 for the BMU root
    'HEYM1': 'GBR1000054', # Heysham 1
    'WHILW1': 'GBR0003489', # WHILW-1, see GBR0003981 for details on separation
    'WHILW2': 'GBR0003981', # This is the extension so should be separated from WHILW-1 like the HEYM group
    'WLNYW1': 'GBR0002500', # WLNYW1
    'WLNYW2': 'GBR0002506', # WLNYW2 - Whilst GPPDB has Walney 1 & 2 it doesnt have the extension included 
    'GNFSW0': 'GBR0002488', # change to GNFSW0
    'GNFSW1': 'GBR0002490', # change to GNFSW1
    'GNFSW2': 'GBR0002489', # change to GNFSW2
    'CRYRW2': 'GBR0003440', # change to CRYRW2 - Crystal Rig Wind Farm - Phase 2
    'CRYRW3': 'GBR0004215', # change to CRYRW3 - Crystal Rig III Wind Farm
    'BLLA1': 'GBR0003116', # change to BLLA1
    'BLLA2': 'GBR0004253', # change to BLLA2
    'WDNSO': 'GBR0002519', # West of Duddon Sands - how to handle OFTO and farm? only WDNSO has data on BMRS
    'THNTO': 'GBR0002499', # could only see FPN for THNTO on BMRS, seems like O is for offtake which is where measurements are made
    'BRYP': 'GBR2000125', # There's also AESB from when it was under AES ownership but no data 
    'CLDW': 'GBR0004178', # The GPPDB only includes the extension at 173 MW but this doesnt match to any of these BMU capacities as shown on netareports - fixed: https://github.com/OSUKED/Power-Station-Dictionary/issues/6
    'PEMB': 'GBR1000372',
    'WBUPS': 'GBR1000143',
    'COTPS': 'GBR1000142',
    'RATS': 'GBR1000496',
    'DRAXX': 'GBR0000174',
    'EGGPS': 'GBR1000147',
    'DINO': 'GBR1000151',
    'STAY': 'GBR1000373',
    'ABTH': 'GBR1000374',
    'DIDCB': 'GBR1000369',
    'GRAI': 'GBR1000495',
    'CNQPS': 'GBR1000492',
    'WBURB': 'GBR1000141',
    'SHBA': 'GBR1000074',
    'HUMR': 'GBR1000517',
    'SCCL': 'GBR2000263',
    'SIZB': 'GBR1000058',
    'TORN': 'GBR1000059',
    'HRTL': 'GBR1000053',
    'PEHEG': 'GBR2000723',
    'DNGB': 'GBR1000052',
    'HUNB': 'GBR1000057',
    'HINB': 'GBR1000056',
    'LAGA': 'GBR1000073',
    'CARR': 'GBR2000124',
    'SPLN': 'GBR0006165',
    'SVRP': 'GBR1000313',
    'MRWD': 'GBR1000311',
    'SUTB': 'GBR2000518',
    'SEAB': 'GBR2000806',
    'ROCK': 'GBR1000212',
    'DAMC': 'GBR1000465',
    'COSO': 'GBR1000211',
    'LBAR': 'GBR1000371',
    'RYHPS': 'GBR1000466',
    'MEDP': 'GBR1000437',
    'LARYW': 'GBR0002511',
    'KILNS': 'GBR1000500',
    'GYMRW': 'GBR0002543',
    'BAGE': 'GBR1000312',
    'DEEP': 'GBR2000262',
    'GRGBW': 'GBR0002510',
    'GYAR': 'GBR1000370',
    'SHOS': 'GBR2000769',
    'SEAB': 'GBR1000480',
    'EECL': 'GBR1000494',
    'CORB': 'GBR1000077',
    'CDCL': 'GBR1000493',
    'FFES': 'GBR1000152',
    'SHRSW': 'GBR0002512',
    'FOYE': 'GBR2000657',
    'RCBKO': 'GBR0002515',
    'LNCSW': 'GBR0002513',
    'BRBEO': 'GBR0002539',
    'PETEM': 'GBR2000128',
    'USKM': 'GBR2000811',
    'PNYCW': 'GBR0004595',
    'HMGTO': 'GBR0002544',
    'WTMSO': 'GBR0002545',
    'GRIFW': 'GBR0004028',
    'FELL': 'GBR1000317',
    'SLOY': 'GBR1000404',
    'BRGG': 'GBR2000126',
    'OMNDW': 'GBR0002509',
    'FALGW': 'GBR0004059',
    'TAYLG': 'GBR1000499',
    'INDQ': 'GBR1000150',
    'COWE': 'GBR1000376',
    'HRSTW': 'GBR0004119',
    'ARCHW': 'GBR0003258',
    'HADHW': 'GBR0003109',
    'BHLAW': 'GBR0004640',
    'DIDCG': 'GBR1000377',
    'GLNDO': 'GBR0000388',
    'FARR': 'GBR0004676',
    'BOWLW': 'GBR0002546',
    'RREW': 'GBR0002496',
    'RRWW': 'GBR0002497',
    'BURBO': 'GBR0002487',
    'BEINW': 'GBR0003787',
    'FERRG': 'GBR0000116',
    'PSTAT002': 'GBR0004627',
    'DRAXXG': 'GBR1000112',
    'BRDUW': 'GBR0003119',
    'GORDW': 'GBR0003662',
    'CGTHW': 'GBR0004664',
    'LCLTW': 'GBR0004123',
    'DRSLW': 'GBR0004269',
    'STRNW': 'GBR0004625',
    'KILBW': 'GBR0002673',
    'BRYBW': 'GBR0004261',
    'GLWSW': 'GBR0004368',
    'MILWW': 'GBR0002723',
    'PPGEN002': 'GBR0004687',
    'TESI': 'GBR0002514',
    'WISTW': 'GBR0004431',
    'CASCLU': 'GBR1000405',
    'AKGLW': 'GBR0004332',
    'MOYEW': 'GBR0003647',
    'PSTAT002': 'GBR0004667',
    'GRAIG': 'GBR1000497',
    'DPGEN001': 'GBR1000114',
    'MKHLW': 'GBR0003260',
    'MPGEN002': 'GBR1000113',
    'RHEI': 'GBR0003552',
    'BABAW': 'GBR0004021',
    'HBHDW': 'GBR0004225',
    'ABTHG': 'GBR1000375',
    'PPGEN001': 'GBR0003534',
    'PSTAT001': 'GBR0003951',
    'MPGEN001': 'GBR1000115',
    'PPGEN003': 'GBR0004006',
    'HLTWW': 'GBR0004014',
    'KILBW': 'GBR0003202',
    'CRMLW': 'GBR0004120',
    'CRGHW': 'GBR0004619',
    'BTUIW': 'GBR0004525',
    'ACHRW': 'GBR0004331',
    'PPGEN001': 'GBR0003534',
    'EDINW': 'GBR0004674',
    'CLAC': 'GBR1000401',
    'WBUGT': 'GBR1000146',
    'MILWW': 'GBR0004682',
    'MINSW': 'GBR0004517',
    'CLDRW': 'GBR0004623',
}

# %% [markdown]
# <br>
#
# We'll now convert the mapping from BMU id to GPPDB id into one from osuked id to GPPDB id

# %%
key_map = {
    k: BMU_root_to_gppd_idnr[v] 
    for k, v 
    in ESAIL_def['key_map'].items() 
    if v 
    in BMU_root_to_gppd_idnr.keys()
}

assert len(key_map) == len(BMU_root_to_gppd_idnr), 'Not all of the GPPDB ids matched to BMU ids were mapped to osuked ids'

# %% [markdown]
# <br>
#
# We'll specify the i/o key columns and attribute column construction definitions

# %%
key_input_col = 'gppd_idnr'
key_output_col = 'gppd_idnr'

attr_cols = {
    'capacity_mw': {
        'output_col': 'capacity_mw',
        'output_rank': 0,
        'value_map': None
    }
}

# %% [markdown]
# <br>
#
# We'll now combine this into a single metadata object

# %%
GPPDB_def = {
    'filename': filename,
    'key_input_col': key_input_col,
    'key_output_col': key_output_col,
    'key_map': key_map,
    'attr_cols': attr_cols
}

JSON(GPPDB_def)

# %% [markdown]
# <br>
#
# And finally save the source definition

# %%
with open(f'{definitions_dir}/GPPDB.json', 'w') as f:
    json.dump(GPPDB_def, f)

# %%
#hide
from nbdev.export import *
notebook2script()
# Out:
# Converted 01-source-data.ipynb.
# Converted 02-data-definitions.ipynb.
# Converted 03-database-construction.ipynb.
# Converted 04-updates-and-cleaning.ipynb.
# Converted 05-pipeline.ipynb.
